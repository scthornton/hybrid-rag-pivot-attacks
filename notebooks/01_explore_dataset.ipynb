# %% [markdown]
# # 01 — Explore Synthetic Enterprise Dataset
#
# This notebook explores the synthetic multi-tenant enterprise corpus
# generated for the PivoRAG experiments.
#
# **Sections:**
# 1. Load and inspect raw documents
# 2. Sensitivity tier distribution per tenant
# 3. Entity extraction statistics
# 4. Graph schema visualization
# 5. Bridge entity analysis (cross-tenant connections)

# %%
import json
from pathlib import Path
from collections import Counter

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

DATA_DIR = Path("../data/raw")
PROCESSED_DIR = Path("../data/processed")

# %% [markdown]
# ## 1. Load Raw Documents

# %%
# TODO: Load synthetic_enterprise.json and display summary statistics
# docs = json.loads((DATA_DIR / "synthetic_enterprise.json").read_text())
# print(f"Total documents: {len(docs)}")

# %% [markdown]
# ## 2. Sensitivity Distribution

# %%
# TODO: Plot sensitivity tier distribution per tenant
# Expected tiers: PUBLIC (40%), INTERNAL (30%), CONFIDENTIAL (20%), RESTRICTED (10%)

# %% [markdown]
# ## 3. Entity Extraction Stats

# %%
# TODO: Run entity extraction and show type distribution
# from pivorag.ingestion.entity_extract import EntityExtractor

# %% [markdown]
# ## 4. Graph Schema Visualization

# %%
# TODO: Visualize graph schema using networkx
# Show node types, edge types, and cardinalities

# %% [markdown]
# ## 5. Bridge Entity Analysis

# %%
# TODO: Identify and visualize cross-tenant bridge entities
# These are the pivot points that enable Retrieval Pivot Attacks
